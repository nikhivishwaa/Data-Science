# %%
import os

# os.environ['OPENAI_API_KEY'] = 'YOUR_KEY'

# %%
from langchain_openai import OpenAI

llm = OpenAI(temperature=0.6)

# %%
llm("give me 7 wonders name")
# Out:
# C:\Users\Nikhil Vishwakarma\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 llm("give me 7 wonders name")
#
# File ~\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:1086, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1079 if not isinstance(prompt, str):
#    1080     raise ValueError(
# ...
